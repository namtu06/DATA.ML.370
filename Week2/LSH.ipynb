# %% [markdown]
# # Task 2.1

# %% [markdown]
# # Task 2.2

# %% [markdown]
# # Task 2.3

# %% [markdown]
# ## Task 2.3.1

# %% [markdown]
# ## Task 2.3.2

# %% [markdown]
# ## Task 2.3.3

# %% [markdown]
# ## Task 2.3.4
